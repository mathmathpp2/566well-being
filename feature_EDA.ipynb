# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# !ls
# Out:
# README.md                            features.csv
# college-experience-dataset_EDA.ipynb merge_corr.png
# corr-phq4_score.png                  profile-demographics (1).html
# corr-stress.png                      profile-ema-covid (1).html
# feature_EDA.ipynb                    profile-ema-general (1).html
# feature_make.ipynb                   sens_corr.png
# feature_making(P&D).ipynb

# %%
df = pd.read_csv("features.csv")
df
# Out:
#                                     uid gender   race  cohort_year  is_ios  \
# 0      3569e2f520db9014b4acc4227a6421c1   both  white       2017.0       0
# 1      3569e2f520db9014b4acc4227a6421c1   both  white       2017.0       0
# 2      3569e2f520db9014b4acc4227a6421c1   both  white       2017.0       0
# 3      3569e2f520db9014b4acc4227a6421c1   both  white       2017.0       0
# 4      3569e2f520db9014b4acc4227a6421c1   both  white       2017.0       0
# ...                                 ...    ...    ...          ...     ...
# 34701  2c4f43b2212eee5ba69563f139911138      M  white       2018.0       1
# 34702  8617ddac1f48b148e3683738519b2e7a    NaN    NaN       2018.0       1
# 34703  ea716dd032aaa0dcf8bfa36b1811917f    NaN    NaN       2017.0       1
# 34704  df5e798581def8d477316520953b9171    NaN    NaN          NaN       0
# 34705  e6d71fe4a3c10b075ae1cf51a2fe6cfd    NaN    NaN          NaN       1
#
# ...

# %%
profile_ = ProfileReport(df, title="Profiling Report (Features)")
profile_.to_file("profile-features.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/kirarak/.pyenv/versions/3.11.5/lib/python3.11/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/kirarak/.pyenv/versions/3.11.5/lib/python3.11/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/kirarak/.pyenv/versions/3.11.5/lib/python3.11/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# ...
