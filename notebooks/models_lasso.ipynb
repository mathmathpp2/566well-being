# %%
# %load_ext autoreload
# %autoreload 2

from webbrowser import get
import pandas as pd
from sklearn.metrics import accuracy_score, r2_score
from models import *
import logging
from pretty_logger import get_logger
from pathlib import Path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define subset (ignore all other data)
ema = [f"Y{i}" for i in range(1, 8, 1)]
physical = [f"P{i}" for i in range(1, 5, 1)]
social = [f"S{i}" for i in range(1, 8, 1)]

# %%
df = pd.read_csv(datafile)
df["date"] = pd.to_datetime(df["day_survey"])
df["C"] = df["date"].apply(
    lambda date: (
        COVIDStatus.POST_COVID if date > date_covid else COVIDStatus.PRE_COVID
    )
)

df_head = df.head(5).copy()

df.rename(columns=reverse_ema_dictionary, inplace=True)
df.set_index(["uid", "date"], inplace=True)

subset = ema + physical + social + sleep + ["C"]
df = df[subset]
df.dropna(inplace=True)

sets_df = pd.read_parquet(sets_file, engine="pyarrow")

# %%
skip_emas = list(set(ema_dictionary.keys()).difference(set(["Y2", "Y3"])))
skip_treatments = list(
    set(subset).difference(
        set(
            [
                "P1",
                "P4",
                # "S1",
                # "S2",
                "S3",
                # "S4",
                "S5",
                "S6",
                # "Z1",
                # "Z2",
                # "Z3",
            ]
        )
    )
)

skip_treatments
# Out:
# ['Z3',
#  'Y6',
#  'Y7',
#  'P3',
#  'P2',
#  'Y4',
#  'S2',
#  'Y1',
#  'Y3',
#  'S7',
#  'Y5',
#  'C',
#  'Z2',
#  'S4',
#  'S1',
#  'Y2',
#  'Z1']

# %%
# index = 17
# model_row = sets_df.iloc[index]

alphas = [0.2, 1, 2]
n_estimatorss = [400]

for n_estimators in n_estimatorss:
    for alpha in alphas:
        for index, model_row in sets_df.iterrows():
            already_fitted_sets = []

            covariate_set = CovariateSet(
                row=model_row,
                data=df,
                outcomes_to_skip=skip_emas,
                treatments_to_skip=skip_treatments,
            )

            if not covariate_set.valid_set:
                logger.debug(f"Skipping {covariate_set} (no valid set)")
                continue

            if covariate_set.set_to_fit in already_fitted_sets:
                logger.info(
                    f"Skipping {covariate_set} (already did {covariate_set.set_to_fit})"
                )
                continue
            already_fitted_sets.append(covariate_set.set_to_fit)

            logger.info(f"Fitting\n{covariate_set!r}")
            logger.info(
                f"Median of {covariate_set.treatment} {df[covariate_set.treatment].median()}"
            )
            wbm = WBLassoModel(
                data=df,
                alpha=alpha,
                treatment=covariate_set.treatment,
                outcome=covariate_set.outcome,
                separating_set=covariate_set.restricted_adjustment_set,
                name=f"row:{index}",
            )
            logger.info(
                f"\nalpha ={alpha}"
                f"pre_rsq train={wbm.pre_r_squared[0]}, pre_rsq test={wbm.pre_r_squared[1]}\n"
                f"pre mae test ={wbm.pre_r_squared[2]}\n"
                f"post_rsq train={wbm.post_r_squared[0]}, post_rsq test={wbm.post_r_squared[1]}\n"
            )
            logger.info(
                "-----------------------------------------------------\n"
            )
# Out:
# [2024-05-28 16:01:02.196] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P4', 'P2', 'S2', 'S6', 'S1', 'S4', 'S3'}
# [2024-05-28 16:01:02.198] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:01:02.352] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.005327016357147607, pre_rsq test=0.004099648812585621
# pre mae test =1.9393051984014154
# post_rsq train=0.00532569797741167, post_rsq test=0.005967558516693061
#
# [2024-05-28 16:01:02.353] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:02.355] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'S5'}
# [2024-05-28 16:01:02.356] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:02.558] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.002859385789646396, pre_rsq test=0.0014815402419640078
# pre mae test =1.9163121109534262
# post_rsq train=0.005134042614896472, post_rsq test=0.00738595779034823
#
# [2024-05-28 16:01:02.559] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:02.561] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:02.562] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:02.759] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.01692799041106685, pre_rsq test=0.013923093266307807
# pre mae test =1.8892657183766095
# post_rsq train=0.04136190255629735, post_rsq test=0.0075079364004256854
#
# [2024-05-28 16:01:02.760] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:02.761] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:02.763] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:02.937] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.01504918207496364, pre_rsq test=0.01524039286309331
# pre mae test =1.9436263880689055
# post_rsq train=0.03410561838175119, post_rsq test=0.030022998812116786
#
# [2024-05-28 16:01:02.939] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:02.940] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:02.941] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:03.131] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.015073645673490899, pre_rsq test=0.019848283602979078
# pre mae test =1.951273662545585
# post_rsq train=0.03352063849343956, post_rsq test=0.03561483849846114
#
# [2024-05-28 16:01:03.132] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:03.134] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'P1'}
# [2024-05-28 16:01:03.136] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:03.319] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.007700467157130242, pre_rsq test=0.004163317461039262
# pre mae test =1.0744337474352643
# post_rsq train=0.07707792365213062, post_rsq test=0.03677367549110777
#
# [2024-05-28 16:01:03.320] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:03.322] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:03.323] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:03.522] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.016129406975784466, pre_rsq test=0.014695722873338535
# pre mae test =1.0655314573445673
# post_rsq train=0.06757476410667995, post_rsq test=0.07232550215288502
#
# [2024-05-28 16:01:03.523] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:03.525] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:03.526] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:03.708] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.01628250326823799, pre_rsq test=0.01454209890454905
# pre mae test =1.0645423464076098
# post_rsq train=0.07363492596219723, post_rsq test=0.04977396396962197
#
# [2024-05-28 16:01:03.709] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:03.711] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P4', 'P2', 'S2', 'S7', 'S1', 'S4', 'S3', 'S5'}
# [2024-05-28 16:01:03.712] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:03.876] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =0.2pre_rsq train=0.017327094850934532, pre_rsq test=0.011013079511701718
# pre mae test =1.0701165875527694
# post_rsq train=0.02995234809862979, post_rsq test=0.010940416659449781
#
# [2024-05-28 16:01:03.877] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:03.886] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P4', 'P2', 'S2', 'S6', 'S1', 'S4', 'S3'}
# [2024-05-28 16:01:03.888] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:01:04.049] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.0036311816905765237, pre_rsq test=0.0031007257303211633
# pre mae test =1.970171038172021
# post_rsq train=0.0044080586327822635, post_rsq test=0.0030433161240605022
#
# [2024-05-28 16:01:04.051] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.052] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'S5'}
# [2024-05-28 16:01:04.054] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:04.216] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.0026638955598822234, pre_rsq test=-0.0026229138133975205
# pre mae test =1.9371012411364479
# post_rsq train=0.004344533637143599, post_rsq test=-0.011480324377810547
#
# [2024-05-28 16:01:04.218] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.220] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:04.222] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:04.382] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.0095799283365402, pre_rsq test=0.01018025178120796
# pre mae test =1.9292368839757297
# post_rsq train=0.041414173736058046, post_rsq test=-0.0174748595084957
#
# [2024-05-28 16:01:04.384] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.386] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:04.387] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:04.547] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.00892962126977237, pre_rsq test=0.01098750007589755
# pre mae test =1.9382683985443254
# post_rsq train=0.03438944923046561, post_rsq test=0.017686352868645727
#
# [2024-05-28 16:01:04.549] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.551] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:04.552] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:04.751] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.011123252998606281, pre_rsq test=0.0038545210987253054
# pre mae test =1.8888769897080355
# post_rsq train=0.03286286566033225, post_rsq test=0.02734297784079931
#
# [2024-05-28 16:01:04.753] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.756] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'P1'}
# [2024-05-28 16:01:04.758] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:04.955] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.006094594080351623, pre_rsq test=0.0021371804006803385
# pre mae test =1.0983948252889422
# post_rsq train=0.07015986228602855, post_rsq test=0.045552428044056126
#
# [2024-05-28 16:01:04.957] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:04.959] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:04.961] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:05.118] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.011094351027368776, pre_rsq test=0.014789628342757766
# pre mae test =1.0724463917476657
# post_rsq train=0.06170092113863823, post_rsq test=0.07903189290655632
#
# [2024-05-28 16:01:05.120] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.121] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:05.123] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:05.274] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.012060823430202205, pre_rsq test=0.010125928835665543
# pre mae test =1.0704695637827817
# post_rsq train=0.06220206314793564, post_rsq test=0.07102342892959501
#
# [2024-05-28 16:01:05.276] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.277] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P4', 'P2', 'S2', 'S7', 'S1', 'S4', 'S3', 'S5'}
# [2024-05-28 16:01:05.279] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:05.446] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =1pre_rsq train=0.01120532103965044, pre_rsq test=0.014658246872151226
# pre mae test =1.0719436998381708
# post_rsq train=0.025817628511220603, post_rsq test=0.011822539570160884
#
# [2024-05-28 16:01:05.448] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.458] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P4', 'P2', 'S2', 'S6', 'S1', 'S4', 'S3'}
# [2024-05-28 16:01:05.460] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:01:05.616] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.003556482470958744, pre_rsq test=0.003434683473293565
# pre mae test =1.9302296629114015
# post_rsq train=0.005518376978663753, post_rsq test=-0.002771620294939714
#
# [2024-05-28 16:01:05.618] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.620] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'S5'}
# [2024-05-28 16:01:05.622] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:05.783] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.001363520817255992, pre_rsq test=0.0029893342257599764
# pre mae test =1.9183309826066741
# post_rsq train=0.0021045380236310862, post_rsq test=-0.004115306222674642
#
# [2024-05-28 16:01:05.784] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.785] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:05.786] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:05.969] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.007059615693445931, pre_rsq test=0.007223554477105654
# pre mae test =1.930033989311203
# post_rsq train=0.0357022657099243, post_rsq test=0.015797996212324694
#
# [2024-05-28 16:01:05.970] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:05.971] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:05.972] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:06.130] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.005342164009428552, pre_rsq test=0.008582527955324215
# pre mae test =1.9441112402870453
# post_rsq train=0.029126299507301057, post_rsq test=0.02927636013118795
#
# [2024-05-28 16:01:06.131] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:06.132] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P4', 'P3', 'P2', 'S2', 'S7', 'S4', 'S1', 'P1', 'Z1'}
# [2024-05-28 16:01:06.134] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:06.348] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.007683178159971438, pre_rsq test=0.007367838774087199
# pre mae test =1.8618498985114171
# post_rsq train=0.030976589061046944, post_rsq test=0.03090403391229457
#
# [2024-05-28 16:01:06.349] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:06.351] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P3', 'P2', 'S3', 'S4', 'S1', 'P1'}
# [2024-05-28 16:01:06.353] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:01:06.511] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.0054272937741571825, pre_rsq test=0.007559719688772781
# pre mae test =1.086316803833992
# post_rsq train=0.07052810419797517, post_rsq test=0.03628204616351527
#
# [2024-05-28 16:01:06.512] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:06.513] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:06.514] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:01:06.693] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.006396248015742123, pre_rsq test=0.005286944463932186
# pre mae test =1.100847073444831
# post_rsq train=0.06583339969006863, post_rsq test=0.07204624097247936
#
# [2024-05-28 16:01:06.694] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:06.695] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'S2', 'P1', 'P2', 'S7'}
# [2024-05-28 16:01:06.697] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:01:06.844] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.005147776425893924, pre_rsq test=0.005965175931723632
# pre mae test =1.0928661758097988
# post_rsq train=0.0672742506822992, post_rsq test=0.06348633251617253
#
# [2024-05-28 16:01:06.845] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:01:06.847] - modelslog- INFO N/A- 3875355891.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P4', 'P2', 'S2', 'S7', 'S1', 'S4', 'S3', 'S5'}
# [2024-05-28 16:01:06.848] - modelslog- INFO N/A- 3875355891.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:01:07.029] - modelslog- INFO N/A- 3875355891.py: 42 [<module>]:
# alpha =2pre_rsq train=0.005785036234732366, pre_rsq test=0.008647032204222471
# pre mae test =1.0494031013746352
# post_rsq train=0.013806686462310758, post_rsq test=0.008932969248327871
#
# [2024-05-28 16:01:07.030] - modelslog- INFO N/A- 3875355891.py: 48 [<module>]: -----------------------------------------------------
