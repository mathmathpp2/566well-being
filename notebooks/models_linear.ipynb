# %%
# %load_ext autoreload
# %autoreload 2

from webbrowser import get
import pandas as pd
from sklearn.metrics import accuracy_score, r2_score
from models import *
import logging
from pretty_logger import get_logger
from pathlib import Path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define subset (ignore all other data)
ema = [f"Y{i}" for i in range(1, 8, 1)]
physical = [f"P{i}" for i in range(1, 5, 1)]
social = [f"S{i}" for i in range(1, 8, 1)]

# %%
df = pd.read_csv(datafile)
df["date"] = pd.to_datetime(df["day_survey"])
df["C"] = df["date"].apply(
    lambda date: (
        COVIDStatus.POST_COVID if date > date_covid else COVIDStatus.PRE_COVID
    )
)

df_head = df.head(5).copy()

df.rename(columns=reverse_ema_dictionary, inplace=True)
df.set_index(["uid", "date"], inplace=True)

subset = ema + physical + social + sleep + demographic + ["C"]
df = df[subset]
df.dropna(inplace=True)

sets_df = pd.read_parquet(sets_file, engine="pyarrow")

# %%
skip_treatments = []
skip_outcomes = []

# %%
alphas = [0]

for alpha in alphas:
    for index, model_row in sets_df.iterrows():
        already_fitted_sets = []

        covariate_set = CovariateSet(
            row=model_row,
            data=df,
            outcomes_to_skip=skip_outcomes,
            treatments_to_skip=skip_treatments,
        )

        if not covariate_set.valid_set:

            logger.error(
                f"Skipping {covariate_set} (no valid set for "
                f"outcome:{model_row['outcome']}, "
                f"treatment:{model_row['treatment']}, "
                f"set:{model_row['sets']})."
            )
            raise ValueError("Invalid set")
            continue

        already_fitted_sets.append(covariate_set.set_to_fit)

        logger.info(f"Fitting\n{covariate_set!r}")
        logger.info(
            f"Median of {covariate_set.treatment} {df[covariate_set.treatment].median()}"
        )
        wbm = WBLinearModel(
            data=df,
            alpha=alpha,
            treatment=covariate_set.treatment,
            outcome=covariate_set.outcome,
            separating_set=covariate_set.restricted_adjustment_set,
            name=f"row:{index}",
        )
        logger.info(
            f"pre_rsq train={wbm.pre_r_squared[0]}, pre_rsq test={wbm.pre_r_squared[1]}\n"
            f"pre mae test ={wbm.pre_r_squared[2]}\n"
            f"post_rsq train={wbm.post_r_squared[0]}, post_rsq test={wbm.post_r_squared[1]}\n"
        )
        logger.info("-----------------------------------------------------\n")
# Out:
# [2024-05-28 23:08:13.167] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D2:race, outcome: Y1:pam, adjustment set={'D1', 'S2', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:13.169] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D2 1.0
# [2024-05-28 23:08:13.287] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05919075256500028, pre_rsq test=0.048916329798104896
# pre mae test =-4.581224844531386e-06
# post_rsq train=0.06755942602708265, post_rsq test=0.055213106390584854
#
# [2024-05-28 23:08:13.288] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:13.289] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D4:cohort year, outcome: Y1:pam, adjustment set={'S7', 'D1', 'S2', 'S6', 'P1', 'D3'}
# [2024-05-28 23:08:13.291] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D4 1.0
# [2024-05-28 23:08:13.399] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.059340535344956646, pre_rsq test=0.06159010456192138
# pre mae test =-8.627846899709652e-06
# post_rsq train=0.0782667492745478, post_rsq test=0.05149917115134828
#
# [2024-05-28 23:08:13.399] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:13.401] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P2:studying (hours), outcome: Y1:pam, adjustment set={'S7', 'D1', 'S5', 'S2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:13.403] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P2 2.719055555553
# [2024-05-28 23:08:13.537] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.060092115625325127, pre_rsq test=0.06004964236342314
# pre mae test =2.628744466654264e-05
# post_rsq train=0.07220647097466559, post_rsq test=0.07747296055406294
#
# [2024-05-28 23:08:13.538] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:13.539] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y1:pam, adjustment set={'S7', 'D1', 'D2', 'S2', 'S3', 'S1', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:13.542] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:13.677] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05468926603648572, pre_rsq test=0.06647053670754755
# pre mae test =4.9095454073552064e-05
# post_rsq train=0.06439453498339742, post_rsq test=0.07245621850336181
#
# [2024-05-28 23:08:13.678] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:13.681] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y1:pam, adjustment set={'D1', 'D2', 'S3', 'P3', 'S1', 'P2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:13.682] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:13.811] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05772553371914135, pre_rsq test=0.061405743568043625
# pre mae test =-1.339792523242872e-06
# post_rsq train=0.07929879191707545, post_rsq test=0.0350109788793318
#
# [2024-05-28 23:08:13.812] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:13.813] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S1:traveling (seconds), outcome: Y1:pam, adjustment set={'D2', 'S2', 'S3', 'P3', 'P2', 'P1', 'D3', 'P4', 'S4'}
# [2024-05-28 23:08:13.816] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S1 854.1666666666666
# [2024-05-28 23:08:14.053] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.057429387970241, pre_rsq test=0.05426768709171892
# pre mae test =8.616502348623921e-06
# post_rsq train=0.06491105873236114, post_rsq test=0.05884649209935011
#
# [2024-05-28 23:08:14.055] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.056] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y1:pam, adjustment set={'S7', 'D1', 'S5', 'S2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:14.058] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:14.252] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.06013480639211666, pre_rsq test=0.05987992105011408
# pre mae test =3.953997077937609e-05
# post_rsq train=0.0772643634501392, post_rsq test=0.05395391658802373
#
# [2024-05-28 23:08:14.254] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.255] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S4:visits, outcome: Y1:pam, adjustment set={'S7', 'D1', 'S2', 'S6', 'P1', 'D3'}
# [2024-05-28 23:08:14.257] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S4 4.7
# [2024-05-28 23:08:14.389] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05906684588890643, pre_rsq test=0.06548936595484134
# pre mae test =-3.572995164029429e-05
# post_rsq train=0.07999462774721611, post_rsq test=0.038391397173254904
#
# [2024-05-28 23:08:14.390] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.391] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y1:pam, adjustment set={'D1', 'S2', 'S6', 'S3', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:14.392] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:14.511] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05962170861380589, pre_rsq test=0.06201456256537008
# pre mae test =-1.692390315584497e-05
# post_rsq train=0.07492842495962149, post_rsq test=0.07404972688220779
#
# [2024-05-28 23:08:14.512] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.513] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D1:gender, outcome: Y2:phq4_score, adjustment set={'S7', 'D2', 'S2', 'S6', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:14.514] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D1 0.0
# [2024-05-28 23:08:14.624] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03222451732779319, pre_rsq test=0.014675043033038015
# pre mae test =-7.962243570096354e-06
# post_rsq train=0.06434818160438671, post_rsq test=0.05048876447834183
#
# [2024-05-28 23:08:14.625] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.626] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'D1', 'D2', 'S2', 'S3', 'S6', 'S1', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:14.628] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P1 10963.4
# [2024-05-28 23:08:14.801] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03657744293794829, pre_rsq test=0.0359645495482136
# pre mae test =-2.4979192755151476e-06
# post_rsq train=0.06078898823199175, post_rsq test=0.06051831344777492
#
# [2024-05-28 23:08:14.802] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:14.803] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P2:studying (hours), outcome: Y2:phq4_score, adjustment set={'S7', 'D1', 'D2', 'S5', 'S2', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:14.806] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P2 2.719055555553
# [2024-05-28 23:08:15.005] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03344278380088461, pre_rsq test=0.025717485662436923
# pre mae test =8.488806284119254e-06
# post_rsq train=0.06259847327724932, post_rsq test=0.062093838598524465
#
# [2024-05-28 23:08:15.006] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.008] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y2:phq4_score, adjustment set={'S7', 'D2', 'S2', 'Z1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:15.010] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:15.146] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03899542041582782, pre_rsq test=0.03470094998897211
# pre mae test =-1.1770555514456526e-06
# post_rsq train=0.05460186002547496, post_rsq test=0.044856752702756686
#
# [2024-05-28 23:08:15.147] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.149] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'D1', 'D2', 'S5', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:15.151] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:15.272] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.040007725954975704, pre_rsq test=0.016817745822252927
# pre mae test =-1.1135454394029284e-05
# post_rsq train=0.06370732754811448, post_rsq test=0.07733452977839639
#
# [2024-05-28 23:08:15.273] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.275] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S1:traveling (seconds), outcome: Y2:phq4_score, adjustment set={'D2', 'S5', 'S2', 'S3', 'P3', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:15.281] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S1 854.1666666666666
# [2024-05-28 23:08:15.436] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03703073269499135, pre_rsq test=0.030839876569954905
# pre mae test =1.0472840673944812e-05
# post_rsq train=0.05728790627278035, post_rsq test=0.04405868681160319
#
# [2024-05-28 23:08:15.438] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.440] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'S7', 'D1', 'S2', 'Z1', 'P3', 'S1', 'P2', 'P1', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:15.442] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:15.571] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.054207753326427244, pre_rsq test=0.03782542610692152
# pre mae test =-8.632698748560945e-06
# post_rsq train=0.06579651910510642, post_rsq test=0.04026676933680762
#
# [2024-05-28 23:08:15.573] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.575] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'S7', 'D1', 'S2', 'Z1', 'P3', 'S1', 'P2', 'P1', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:15.577] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:15.706] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.051746650540974715, pre_rsq test=0.050794489785546904
# pre mae test =8.868593368646734e-06
# post_rsq train=0.06438266571744, post_rsq test=0.0577414129745607
#
# [2024-05-28 23:08:15.708] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.710] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'S7', 'D1', 'S2', 'Z1', 'P3', 'S1', 'P2', 'P1', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:15.711] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:15.837] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0517326091180883, pre_rsq test=0.04887299198505868
# pre mae test =-4.219444978184899e-07
# post_rsq train=0.06436148942633313, post_rsq test=0.05439794712436807
#
# [2024-05-28 23:08:15.839] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.841] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D1:gender, outcome: Y3:phq2_score, adjustment set={'S7', 'D2', 'S2', 'S3', 'S1', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:15.843] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D1 0.0
# [2024-05-28 23:08:15.972] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.041399331660685545, pre_rsq test=0.040198439932506935
# pre mae test =2.1324772935766516e-05
# post_rsq train=0.09402462008566781, post_rsq test=0.12441202573960541
#
# [2024-05-28 23:08:15.974] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:15.976] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D2:race, outcome: Y3:phq2_score, adjustment set={'D1', 'S2', 'S3', 'P3', 'P2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:15.977] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D2 1.0
# [2024-05-28 23:08:16.082] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0384397843960137, pre_rsq test=0.04271777231374496
# pre mae test =5.054003140806857e-06
# post_rsq train=0.11257714306471356, post_rsq test=0.06469097691176107
#
# [2024-05-28 23:08:16.084] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.086] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y3:phq2_score, adjustment set={'S7', 'D2', 'S2', 'S3', 'S1', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:16.088] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:16.211] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0440460979419387, pre_rsq test=0.031146513222440664
# pre mae test =1.4214258233794945e-05
# post_rsq train=0.09725938749428176, post_rsq test=0.07561432122744172
#
# [2024-05-28 23:08:16.213] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.215] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'D1', 'D2', 'S3', 'P3', 'S1', 'P2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:16.217] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:16.341] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04126051583763912, pre_rsq test=0.050299161545970805
# pre mae test =2.6915709415424638e-06
# post_rsq train=0.10537715907721124, post_rsq test=0.1286639517048026
#
# [2024-05-28 23:08:16.343] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.344] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S1:traveling (seconds), outcome: Y3:phq2_score, adjustment set={'D1', 'S2', 'S3', 'P3', 'P2', 'P1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:16.346] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S1 854.1666666666666
# [2024-05-28 23:08:16.496] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04062905456562027, pre_rsq test=0.03837026295688617
# pre mae test =6.467455563206984e-06
# post_rsq train=0.11593158516062096, post_rsq test=0.05677086819636834
#
# [2024-05-28 23:08:16.498] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.500] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'S7', 'S2', 'P2', 'P1', 'D3', 'D4'}
# [2024-05-28 23:08:16.502] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:16.621] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04114916187486706, pre_rsq test=0.029472048577016574
# pre mae test =3.6785861799032202e-06
# post_rsq train=0.089199241831591, post_rsq test=0.08704553403747262
#
# [2024-05-28 23:08:16.622] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.624] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S4:visits, outcome: Y3:phq2_score, adjustment set={'S7', 'D1', 'S3', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:16.626] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S4 4.7
# [2024-05-28 23:08:16.746] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0461549331717912, pre_rsq test=0.028700976976750447
# pre mae test =-1.0689564197894422e-05
# post_rsq train=0.11219367325201512, post_rsq test=0.07156955104182194
#
# [2024-05-28 23:08:16.748] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.749] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'S7', 'S2', 'P2', 'P1', 'D3', 'D4'}
# [2024-05-28 23:08:16.751] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:16.873] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04072270878017936, pre_rsq test=0.03243907821478775
# pre mae test =-6.645004203159052e-06
# post_rsq train=0.09476833232826576, post_rsq test=0.05675050692164674
#
# [2024-05-28 23:08:16.875] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:16.876] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'S7', 'D2', 'S5', 'S2', 'S3', 'S1', 'P2', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:16.878] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:17.025] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04351522420962872, pre_rsq test=0.03373502319697774
# pre mae test =-1.0998279762278367e-06
# post_rsq train=0.09899889023229247, post_rsq test=0.06422606859592861
#
# [2024-05-28 23:08:17.026] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.028] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D1:gender, outcome: Y4:gad2_score, adjustment set={'Z2', 'S2', 'Z1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:17.029] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D1 0.0
# [2024-05-28 23:08:17.137] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03796067341256315, pre_rsq test=0.03540585740010593
# pre mae test =7.3726599250715785e-06
# post_rsq train=0.03131969670859902, post_rsq test=0.04656118367735129
#
# [2024-05-28 23:08:17.138] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.140] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D2:race, outcome: Y4:gad2_score, adjustment set={'S7', 'D1', 'Z2', 'S5', 'S2', 'Z1', 'P3', 'S1', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:17.142] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D2 1.0
# [2024-05-28 23:08:17.253] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.040286142394710844, pre_rsq test=0.04230184432733486
# pre mae test =3.1691512975474136e-06
# post_rsq train=0.05060302675089534, post_rsq test=0.03970731251853166
#
# [2024-05-28 23:08:17.255] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.256] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y4:gad2_score, adjustment set={'D1', 'Z2', 'D2', 'S5', 'Z1', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:17.258] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P1 10963.4
# [2024-05-28 23:08:17.386] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05129304711690741, pre_rsq test=0.03701137982430369
# pre mae test =3.146379018061935e-06
# post_rsq train=0.057948813479722916, post_rsq test=0.046090191476870546
#
# [2024-05-28 23:08:17.387] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.389] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P2:studying (hours), outcome: Y4:gad2_score, adjustment set={'S7', 'D1', 'D2', 'S5', 'S2', 'P3', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:17.391] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P2 2.719055555553
# [2024-05-28 23:08:17.517] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.02508812842684982, pre_rsq test=0.021280205159494803
# pre mae test =-2.9360801448902994e-05
# post_rsq train=0.03782277688566826, post_rsq test=0.02698800915589117
#
# [2024-05-28 23:08:17.518] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.520] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y4:gad2_score, adjustment set={'Z2', 'S2', 'Z1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:17.522] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:17.645] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03713037808147679, pre_rsq test=0.03862933866548646
# pre mae test =-3.5585241228558556e-06
# post_rsq train=0.03266149086903447, post_rsq test=0.016249300916932108
#
# [2024-05-28 23:08:17.647] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.649] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y4:gad2_score, adjustment set={'D1', 'Z2', 'D2', 'S5', 'Z1', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:17.651] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:17.775] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04564013972861192, pre_rsq test=0.05044411529404558
# pre mae test =1.0595321567784404e-06
# post_rsq train=0.05200540681837351, post_rsq test=0.055443241154812806
#
# [2024-05-28 23:08:17.777] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.779] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S1:traveling (seconds), outcome: Y4:gad2_score, adjustment set={'S7', 'D1', 'D2', 'S5', 'S2', 'P3', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:17.781] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S1 854.1666666666666
# [2024-05-28 23:08:17.925] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.026225379599440823, pre_rsq test=0.030852996136445876
# pre mae test =1.1569575468996422e-05
# post_rsq train=0.04402882645436246, post_rsq test=0.007346356477846205
#
# [2024-05-28 23:08:17.926] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:17.927] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y4:gad2_score, adjustment set={'S7', 'D1', 'S5', 'S2', 'P3', 'S1', 'P2', 'P1', 'D3', 'P4', 'D4', 'S4'}
# [2024-05-28 23:08:17.928] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:18.071] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.029454030580847612, pre_rsq test=0.024170050832163836
# pre mae test =-4.587708106831087e-06
# post_rsq train=0.04366560807171571, post_rsq test=-0.003809105185504036
#
# [2024-05-28 23:08:18.073] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.075] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y4:gad2_score, adjustment set={'Z2', 'S2', 'Z1', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:18.077] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:18.230] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03965032729327511, pre_rsq test=0.028037435613903816
# pre mae test =7.2953920750695116e-06
# post_rsq train=0.034132132905467016, post_rsq test=0.032827021136780155
#
# [2024-05-28 23:08:18.231] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.232] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y4:gad2_score, adjustment set={'D1', 'S5', 'S2', 'Z1', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:18.234] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:18.355] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0370795993818166, pre_rsq test=0.03512048147663194
# pre mae test =-8.814561428684896e-06
# post_rsq train=0.04139784346816233, post_rsq test=0.018227867713010104
#
# [2024-05-28 23:08:18.356] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.357] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S7:motion at social locations (minutes), outcome: Y4:gad2_score, adjustment set={'D1', 'Z2', 'D2', 'S5', 'Z1', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:18.359] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S7 58.9862664203375
# [2024-05-28 23:08:18.480] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05330922693141271, pre_rsq test=0.03815413793985323
# pre mae test =-4.7329694556112033e-07
# post_rsq train=0.05154030430681289, post_rsq test=0.056289195899805744
#
# [2024-05-28 23:08:18.481] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.483] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D4:cohort year, outcome: Y5:social_level, adjustment set={'D1', 'D2', 'S5', 'S3', 'P3', 'P2', 'D3', 'P4'}
# [2024-05-28 23:08:18.484] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D4 1.0
# [2024-05-28 23:08:18.584] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03864810540680497, pre_rsq test=0.03469218651910444
# pre mae test =3.326200686336712e-06
# post_rsq train=0.08565659034763717, post_rsq test=0.13762598531743697
#
# [2024-05-28 23:08:18.585] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.587] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y5:social_level, adjustment set={'D1', 'D2', 'S5', 'S3', 'P3', 'P2', 'D3', 'P4'}
# [2024-05-28 23:08:18.588] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P1 10963.4
# [2024-05-28 23:08:18.704] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.039247550248969976, pre_rsq test=0.03621300602629829
# pre mae test =-2.1777834288036942e-06
# post_rsq train=0.10364205989009145, post_rsq test=0.08290697695008342
#
# [2024-05-28 23:08:18.705] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.706] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P2:studying (hours), outcome: Y5:social_level, adjustment set={'D2', 'S5', 'P3', 'S1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:18.708] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P2 2.719055555553
# [2024-05-28 23:08:18.824] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.038522089979307395, pre_rsq test=0.033607132760406944
# pre mae test =-6.138593357802654e-06
# post_rsq train=0.10341799361635828, post_rsq test=0.08091205484289854
#
# [2024-05-28 23:08:18.825] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.826] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y5:social_level, adjustment set={'D1', 'D2', 'S3', 'P3', 'S1', 'D3', 'D4'}
# [2024-05-28 23:08:18.828] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:18.943] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03604479003659644, pre_rsq test=0.03029654859744646
# pre mae test =-1.4361587722884495e-05
# post_rsq train=0.09942696369725801, post_rsq test=0.09983555066194683
#
# [2024-05-28 23:08:18.944] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:18.946] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S2:distance traveled (meters), outcome: Y5:social_level, adjustment set={'D2', 'S5', 'P3', 'S1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:18.947] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S2 13924.338801653
# [2024-05-28 23:08:19.062] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03768868099991396, pre_rsq test=0.03696969552777163
# pre mae test =2.243535052720473e-06
# post_rsq train=0.1031193210175122, post_rsq test=0.09900285942737896
#
# [2024-05-28 23:08:19.063] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.064] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y5:social_level, adjustment set={'D2', 'S5', 'P3', 'S1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:19.066] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:19.244] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.03765514112020485, pre_rsq test=0.03670697031110881
# pre mae test =-5.853240455050611e-06
# post_rsq train=0.10436113974589356, post_rsq test=0.08794904972953232
#
# [2024-05-28 23:08:19.245] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.246] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S4:visits, outcome: Y5:social_level, adjustment set={'D2', 'S5', 'S2', 'S1', 'P2', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:19.248] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S4 4.7
# [2024-05-28 23:08:19.365] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.031729795170807096, pre_rsq test=0.024186023803933532
# pre mae test =9.555252134274113e-06
# post_rsq train=0.09513187104035525, post_rsq test=0.08252830080433415
#
# [2024-05-28 23:08:19.366] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.368] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y5:social_level, adjustment set={'D1', 'D2', 'S5', 'S2', 'S3', 'P3', 'P2', 'P1', 'D3', 'P4', 'S4'}
# [2024-05-28 23:08:19.369] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:19.487] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04139860713797072, pre_rsq test=0.03812795068967523
# pre mae test =9.790279721316444e-06
# post_rsq train=0.11447158373695332, post_rsq test=0.07573556338283316
#
# [2024-05-28 23:08:19.488] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.489] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S7:motion at social locations (minutes), outcome: Y5:social_level, adjustment set={'D1', 'D2', 'S5', 'S3', 'P3', 'P2', 'P1', 'D3', 'P4', 'S4'}
# [2024-05-28 23:08:19.491] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S7 58.9862664203375
# [2024-05-28 23:08:19.608] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.038821063759623464, pre_rsq test=0.04168964356516347
# pre mae test =1.6198837840041e-05
# post_rsq train=0.10943466773673172, post_rsq test=0.10397902259134761
#
# [2024-05-28 23:08:19.609] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.610] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: D2:race, outcome: Y6:sse_score, adjustment set={'S7', 'D1', 'S5', 'S2', 'S1', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:19.612] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of D2 1.0
# [2024-05-28 23:08:19.713] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05456773114930458, pre_rsq test=0.047349744942854044
# pre mae test =1.9055825905031377e-05
# post_rsq train=0.06617818266216502, post_rsq test=0.06766658670775627
#
# [2024-05-28 23:08:19.714] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.715] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y6:sse_score, adjustment set={'D1', 'D2', 'S2', 'S3', 'S6', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:19.717] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P1 10963.4
# [2024-05-28 23:08:19.875] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05109479356864122, pre_rsq test=0.037654110612137526
# pre mae test =-1.210052464671689e-05
# post_rsq train=0.0646261987896577, post_rsq test=0.03864388621948156
#
# [2024-05-28 23:08:19.876] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.877] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P2:studying (hours), outcome: Y6:sse_score, adjustment set={'S7', 'D1', 'S5', 'S2', 'S1', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:19.879] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P2 2.719055555553
# [2024-05-28 23:08:19.997] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.05159080706547947, pre_rsq test=0.06162346666285101
# pre mae test =-1.8481795782102448e-06
# post_rsq train=0.06938608513440114, post_rsq test=0.07000883459406881
#
# [2024-05-28 23:08:19.998] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:19.999] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y6:sse_score, adjustment set={'S7', 'D1', 'S2', 'Z1', 'S1', 'D3', 'D4'}
# [2024-05-28 23:08:20.001] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:20.116] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.056412771447514, pre_rsq test=0.06181030511605912
# pre mae test =-2.419090067834092e-05
# post_rsq train=0.06014938044612017, post_rsq test=0.022997484145858893
#
# [2024-05-28 23:08:20.117] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.119] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y6:sse_score, adjustment set={'D1', 'D2', 'S2', 'S3', 'S6', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:20.120] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:20.236] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.052808104970326064, pre_rsq test=0.03938905021430594
# pre mae test =-1.5566870754225993e-05
# post_rsq train=0.07208337360162909, post_rsq test=0.046379077391282886
#
# [2024-05-28 23:08:20.237] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.238] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y6:sse_score, adjustment set={'S7', 'D1', 'S5', 'S2', 'S1', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:20.240] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:20.385] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.053961787374796844, pre_rsq test=0.04436200836125148
# pre mae test =-6.221321828123266e-06
# post_rsq train=0.07529166108373553, post_rsq test=0.0674106172987412
#
# [2024-05-28 23:08:20.386] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.387] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S4:visits, outcome: Y6:sse_score, adjustment set={'S7', 'D1', 'S2', 'S6', 'S1', 'P3', 'D3', 'D4'}
# [2024-05-28 23:08:20.388] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S4 4.7
# [2024-05-28 23:08:20.503] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04702344512787082, pre_rsq test=0.04431497809243168
# pre mae test =-3.0386598158911834e-05
# post_rsq train=0.04510964689575325, post_rsq test=0.056623078705536845
#
# [2024-05-28 23:08:20.504] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.505] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y6:sse_score, adjustment set={'D1', 'D2', 'S2', 'S3', 'S6', 'S1', 'P2', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:20.507] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:20.631] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.052518677928650837, pre_rsq test=0.04008391834664293
# pre mae test =-2.3810106153928896e-05
# post_rsq train=0.07545482486344712, post_rsq test=0.053687866739268286
#
# [2024-05-28 23:08:20.632] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.633] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y6:sse_score, adjustment set={'D1', 'S2', 'Z1', 'S3', 'S1', 'P3', 'D3', 'D4', 'S4'}
# [2024-05-28 23:08:20.634] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:20.751] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.058823789301019835, pre_rsq test=0.06793793170098661
# pre mae test =-1.2049277381873446e-05
# post_rsq train=0.07916920088929624, post_rsq test=0.03027844268006985
#
# [2024-05-28 23:08:20.752] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.753] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y7:stress, adjustment set={'S7', 'D1', 'D2', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4'}
# [2024-05-28 23:08:20.755] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P1 10963.4
# [2024-05-28 23:08:20.870] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04180964070627635, pre_rsq test=0.04275422749085367
# pre mae test =1.275834950277795e-05
# post_rsq train=0.03786687018889867, post_rsq test=0.029502206429911082
#
# [2024-05-28 23:08:20.872] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:20.873] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P3:in house (hours), outcome: Y7:stress, adjustment set={'S7', 'D1', 'D2', 'S2', 'S1', 'P2', 'D3', 'D4'}
# [2024-05-28 23:08:20.874] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P3 11.401999999984
# [2024-05-28 23:08:21.013] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04152895585879057, pre_rsq test=0.049074753851231834
# pre mae test =-6.3170773537692325e-06
# post_rsq train=0.039403857815870635, post_rsq test=0.00433256065676646
#
# [2024-05-28 23:08:21.014] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:21.015] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y7:stress, adjustment set={'S7', 'D1', 'D2', 'S3', 'P3', 'S1', 'P2', 'D3', 'D4'}
# [2024-05-28 23:08:21.016] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of P4 0.08325
# [2024-05-28 23:08:21.137] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04203490349750727, pre_rsq test=0.0488241940265588
# pre mae test =9.323296480158187e-06
# post_rsq train=0.04267643553677791, post_rsq test=0.009506296935366865
#
# [2024-05-28 23:08:21.138] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:21.139] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y7:stress, adjustment set={'S7', 'D1', 'S2', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:21.141] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 23:08:21.258] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04171982371289462, pre_rsq test=0.035888311918026994
# pre mae test =-7.231538717497998e-06
# post_rsq train=0.0425404750562971, post_rsq test=0.015228931586311889
#
# [2024-05-28 23:08:21.259] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:21.260] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S4:visits, outcome: Y7:stress, adjustment set={'S7', 'D1', 'S2', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:21.261] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S4 4.7
# [2024-05-28 23:08:21.381] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.0410469063160368, pre_rsq test=0.038443480979697076
# pre mae test =3.784478141143771e-06
# post_rsq train=0.040140517159632294, post_rsq test=0.018229396321680746
#
# [2024-05-28 23:08:21.382] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:21.383] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y7:stress, adjustment set={'S7', 'D1', 'S2', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:21.385] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 23:08:21.503] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04219038184990043, pre_rsq test=0.032712209661657776
# pre mae test =1.456890552384544e-05
# post_rsq train=0.04366708740560088, post_rsq test=0.023498794245154553
#
# [2024-05-28 23:08:21.504] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
#
# [2024-05-28 23:08:21.506] - modelslog- INFO N/A- 1968370032.py: 27 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y7:stress, adjustment set={'S7', 'D1', 'S2', 'S1', 'P3', 'P2', 'P1', 'D3', 'P4', 'D4'}
# [2024-05-28 23:08:21.507] - modelslog- INFO N/A- 1968370032.py: 28 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 23:08:21.625] - modelslog- INFO N/A- 1968370032.py: 39 [<module>]: pre_rsq train=0.04255438161074154, pre_rsq test=0.0339467372501312
# pre mae test =-7.484384800431269e-06
# post_rsq train=0.03388775483895834, post_rsq test=0.04854778000712345
#
# [2024-05-28 23:08:21.626] - modelslog- INFO N/A- 1968370032.py: 44 [<module>]: -----------------------------------------------------
