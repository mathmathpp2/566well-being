# %%
# %load_ext autoreload
# %autoreload 2

from webbrowser import get
import pandas as pd
from sklearn.metrics import accuracy_score, r2_score
from models import *
import logging
from pretty_logger import get_logger
from pathlib import Path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define subset (ignore all other data)
ema = [f"Y{i}" for i in range(1, 8, 1)]
physical = [f"P{i}" for i in range(1, 5, 1)]
social = [f"S{i}" for i in range(1, 8, 1)]

# %%
df = pd.read_csv(datafile)
df["date"] = pd.to_datetime(df["day_survey"])
df["C"] = df["date"].apply(
    lambda date: (
        COVIDStatus.POST_COVID if date > date_covid else COVIDStatus.PRE_COVID
    )
)

df_head = df.head(5).copy()

df.rename(columns=reverse_ema_dictionary, inplace=True)
df.set_index(["uid", "date"], inplace=True)

subset = ema + physical + social + sleep + ["C"]
df = df[subset]
df.dropna(inplace=True)

sets_df = pd.read_parquet(sets_file, engine="pyarrow")

# %%
skip_emas = list(set(ema_dictionary.keys()).difference(set(["Y2", "Y3"])))
skip_treatments = list(
    set(subset).difference(
        set(
            [
                "P1",
                "P4",
                # "S1",
                # "S2",
                "S3",
                # "S4",
                "S5",
                "S6",
                # "Z1",
                # "Z2",
                # "Z3",
            ]
        )
    )
)

skip_treatments
# Out:
# ['P2',
#  'S4',
#  'Y3',
#  'Z2',
#  'Y2',
#  'S1',
#  'Z3',
#  'Y5',
#  'Y6',
#  'Y7',
#  'S2',
#  'C',
#  'P3',
#  'Y4',
#  'S7',
#  'Z1',
#  'Y1']

# %%
# index = 17
# model_row = sets_df.iloc[index]

alphas = [0.2, 1, 2]
n_estimatorss = [400]

for n_estimators in n_estimatorss:
    for alpha in alphas:
        for index, model_row in sets_df.iterrows():
            already_fitted_sets = []

            covariate_set = CovariateSet(
                row=model_row,
                data=df,
                outcomes_to_skip=skip_emas,
                treatments_to_skip=skip_treatments,
            )

            if not covariate_set.valid_set:
                logger.debug(f"Skipping {covariate_set} (no valid set)")
                continue

            if covariate_set.set_to_fit in already_fitted_sets:
                logger.info(
                    f"Skipping {covariate_set} (already did {covariate_set.set_to_fit})"
                )
                continue
            already_fitted_sets.append(covariate_set.set_to_fit)

            logger.info(f"Fitting\n{covariate_set!r}")
            logger.info(
                f"Median of {covariate_set.treatment} {df[covariate_set.treatment].median()}"
            )
            wbm = WBLinearModel(
                data=df,
                treatment=covariate_set.treatment,
                outcome=covariate_set.outcome,
                separating_set=covariate_set.restricted_adjustment_set,
                name=f"row:{index}",
            )
            logger.info(
                f"pre_rsq train={wbm.pre_r_squared[0]}, pre_rsq test={wbm.pre_r_squared[1]}\n"
                f"pre mae test ={wbm.pre_r_squared[2]}\n"
                f"post_rsq train={wbm.post_r_squared[0]}, post_rsq test={wbm.post_r_squared[1]}\n"
            )
            logger.info(
                "-----------------------------------------------------\n"
            )
# Out:
# [2024-05-28 16:03:31.468] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S3', 'S1', 'S2', 'S6'}
# [2024-05-28 16:03:31.470] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:03:31.581] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.011448571829959397, pre_rsq test=0.009545715899704765
# pre mae test =1.9240513911251569
# post_rsq train=0.016545711004101626, post_rsq test=0.026328570007057128
#
# [2024-05-28 16:03:31.582] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:31.583] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'S5', 'S1', 'S3', 'P3'}
# [2024-05-28 16:03:31.585] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:31.707] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.018267938870372813, pre_rsq test=6.234748527633727e-05
# pre mae test =1.937616423500623
# post_rsq train=0.015089394826617197, post_rsq test=-0.0005307491079038495
#
# [2024-05-28 16:03:31.708] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:31.710] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:31.711] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:31.883] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.02801701881106433, pre_rsq test=0.021701608097875802
# pre mae test =1.9141594385268568
# post_rsq train=0.03753616815432226, post_rsq test=0.04551068615444254
#
# [2024-05-28 16:03:31.884] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:31.886] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:31.887] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:32.058] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.027611012061560913, pre_rsq test=0.023553879650335285
# pre mae test =1.8799950965774206
# post_rsq train=0.04165378317923585, post_rsq test=0.03247480955448101
#
# [2024-05-28 16:03:32.059] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.060] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:32.062] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:32.222] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.027279043750475074, pre_rsq test=0.04148625939668282
# pre mae test =1.8484103960732248
# post_rsq train=0.03905976811960632, post_rsq test=0.03805082144159233
#
# [2024-05-28 16:03:32.223] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.225] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'S1', 'P1', 'S3', 'P3'}
# [2024-05-28 16:03:32.228] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:32.379] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.01576801999037858, pre_rsq test=0.019415962324274005
# pre mae test =1.0643080518205452
# post_rsq train=0.0828726621199889, post_rsq test=0.05752781915631722
#
# [2024-05-28 16:03:32.380] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.381] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:32.383] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:32.494] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.01830735128844363, pre_rsq test=0.01957621785613861
# pre mae test =1.0703185159092063
# post_rsq train=0.06950363534665582, post_rsq test=0.08147857590365615
#
# [2024-05-28 16:03:32.495] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.497] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:32.501] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:32.617] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.01722685526711687, pre_rsq test=0.020613656016659765
# pre mae test =1.078981029277191
# post_rsq train=0.07241528525357055, post_rsq test=0.05411697699846574
#
# [2024-05-28 16:03:32.617] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.619] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'P4', 'S5', 'S1', 'S3', 'S2', 'S7'}
# [2024-05-28 16:03:32.621] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:32.806] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.02303846233219009, pre_rsq test=0.014963946259360372
# pre mae test =1.0765984467830176
# post_rsq train=0.02846878425619659, post_rsq test=0.030687947075069166
#
# [2024-05-28 16:03:32.807] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:32.817] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S3', 'S1', 'S2', 'S6'}
# [2024-05-28 16:03:32.819] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:03:32.997] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.011033056351841375, pre_rsq test=0.010437104645207196
# pre mae test =1.9563963895608354
# post_rsq train=0.021254891251414443, post_rsq test=-0.0033283868927473925
#
# [2024-05-28 16:03:32.998] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.000] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'S5', 'S1', 'S3', 'P3'}
# [2024-05-28 16:03:33.002] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:33.165] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.015932456249069804, pre_rsq test=0.010058163674806386
# pre mae test =1.9247881422968394
# post_rsq train=0.013935301725226834, post_rsq test=0.0033244703695037847
#
# [2024-05-28 16:03:33.166] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.168] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:33.170] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:33.352] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.028203096513108927, pre_rsq test=0.02171784649397912
# pre mae test =1.9447965928047124
# post_rsq train=0.0415189011244822, post_rsq test=0.033892910141651855
#
# [2024-05-28 16:03:33.353] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.354] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:33.356] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:33.549] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.026866587596140246, pre_rsq test=0.026477214399309168
# pre mae test =1.9441294105601885
# post_rsq train=0.03826733895898349, post_rsq test=0.044691475317375495
#
# [2024-05-28 16:03:33.550] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.551] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:33.553] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:33.726] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.029486482179252427, pre_rsq test=0.032489637318761644
# pre mae test =1.885170866694431
# post_rsq train=0.039960530972052655, post_rsq test=0.04058166961031939
#
# [2024-05-28 16:03:33.729] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.731] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'S1', 'P1', 'S3', 'P3'}
# [2024-05-28 16:03:33.733] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:33.890] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.01588256197537785, pre_rsq test=0.019028634862207072
# pre mae test =1.0456004493455877
# post_rsq train=0.08404004832959266, post_rsq test=0.05248811447878732
#
# [2024-05-28 16:03:33.891] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:33.893] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:33.895] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:34.010] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.019314164817659463, pre_rsq test=0.015505862795227476
# pre mae test =1.0455565944985108
# post_rsq train=0.08182956922920515, post_rsq test=0.02953485629470476
#
# [2024-05-28 16:03:34.011] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.013] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:34.015] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:34.128] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.018680409405449794, pre_rsq test=0.01579342478228818
# pre mae test =1.0627739856401963
# post_rsq train=0.07465286549436734, post_rsq test=0.04753099176747566
#
# [2024-05-28 16:03:34.129] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.132] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'P4', 'S5', 'S1', 'S3', 'S2', 'S7'}
# [2024-05-28 16:03:34.134] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:34.315] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.02330688499181055, pre_rsq test=0.016786548506160126
# pre mae test =1.07255243003399
# post_rsq train=0.02904759001525281, post_rsq test=0.02909382023814433
#
# [2024-05-28 16:03:34.316] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.326] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P1:excercise (seconds), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S3', 'S1', 'S2', 'S6'}
# [2024-05-28 16:03:34.327] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P1 10963.4
# [2024-05-28 16:03:34.468] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.011652926657847007, pre_rsq test=0.007885398315213732
# pre mae test =1.908430704239096
# post_rsq train=0.018230032685914166, post_rsq test=0.02136601683231809
#
# [2024-05-28 16:03:34.469] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.471] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'S5', 'S1', 'S3', 'P3'}
# [2024-05-28 16:03:34.472] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:34.614] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.014632352043351338, pre_rsq test=0.013180927785140684
# pre mae test =1.9497817000871396
# post_rsq train=0.011777860712672505, post_rsq test=0.013846824845053729
#
# [2024-05-28 16:03:34.615] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.616] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:34.617] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:34.778] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.028112643158897166, pre_rsq test=0.021873057991941502
# pre mae test =1.9016606881973304
# post_rsq train=0.03967678881534831, post_rsq test=0.02416539753645386
#
# [2024-05-28 16:03:34.779] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.780] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:34.782] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:34.949] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.026494538594699524, pre_rsq test=0.028757123758537895
# pre mae test =1.90273470296581
# post_rsq train=0.041912910548985716, post_rsq test=0.034585060336341455
#
# [2024-05-28 16:03:34.950] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:34.952] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y2:phq4_score, adjustment set={'P2', 'S4', 'P4', 'S1', 'P1', 'P3', 'S2', 'S7', 'Z1'}
# [2024-05-28 16:03:34.953] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:35.098] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.029265735128035097, pre_rsq test=0.03308849111597478
# pre mae test =1.8834204123273093
# post_rsq train=0.03942614056434035, post_rsq test=0.043520180863905744
#
# [2024-05-28 16:03:35.099] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:35.101] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: P4:sports (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'S1', 'P1', 'S3', 'P3'}
# [2024-05-28 16:03:35.102] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of P4 0.08325
# [2024-05-28 16:03:35.232] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.018087710670720902, pre_rsq test=0.009974197788303663
# pre mae test =1.0704249499137053
# post_rsq train=0.07361132207634702, post_rsq test=0.09573596586152278
#
# [2024-05-28 16:03:35.233] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:35.234] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S3:time in social location (hours), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:35.236] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S3 1.2667499999993
# [2024-05-28 16:03:35.352] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.020037662517542687, pre_rsq test=0.01120766805002027
# pre mae test =1.053730781985931
# post_rsq train=0.07146899047282507, post_rsq test=0.0750522801192186
#
# [2024-05-28 16:03:35.353] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:35.354] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S5:duration unlocked phone in social locations (minutes), outcome: Y3:phq2_score, adjustment set={'P2', 'P1', 'S7', 'S2'}
# [2024-05-28 16:03:35.356] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S5 10.337346295043334
# [2024-05-28 16:03:35.472] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.017472688746118847, pre_rsq test=0.020003129141518472
# pre mae test =1.0701383355161702
# post_rsq train=0.05650797174359801, post_rsq test=0.11122372569362293
#
# [2024-05-28 16:03:35.473] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
#
# [2024-05-28 16:03:35.475] - modelslog- INFO N/A- 736066224.py: 30 [<module>]: Fitting
# treatment: S6:frequency of unlocked phone in social locations, outcome: Y3:phq2_score, adjustment set={'P2', 'S4', 'P4', 'S5', 'S1', 'S3', 'S2', 'S7'}
# [2024-05-28 16:03:35.476] - modelslog- INFO N/A- 736066224.py: 31 [<module>]: Median of S6 8.956802500082901
# [2024-05-28 16:03:35.629] - modelslog- INFO N/A- 736066224.py: 41 [<module>]: pre_rsq train=0.024224811797915358, pre_rsq test=0.012360856967963851
# pre mae test =1.0605415536693827
# post_rsq train=0.03569840245971856, post_rsq test=0.0015650011351298065
#
# [2024-05-28 16:03:35.630] - modelslog- INFO N/A- 736066224.py: 46 [<module>]: -----------------------------------------------------
